# %%
! pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.8 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 36.7 MB/s
# ...
#      |████████████████████████████████| 636 kB 38.2 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 45.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
import pandas as pd
df_fr=pd.read_csv('/content/df_fr_en.csv')

# %%
len(df_fr)
# Out:
# 24398

# %%
df_message=df_fr['message_fr_en']
df_message = df_message.dropna()

# %%
df1=df_message.values.tolist()

# %%
df_fr.dropna(subset=['message_fr_en'])
# Out:
#        Unnamed: 0  ... comp_score
# 0               0  ...        pos
# 1               1  ...        pos
# 2               2  ...        pos
# 3               3  ...       neut
# 4               4  ...       neut
# ...           ...  ...        ...
# 24393       24393  ...        pos
# 24394       24394  ...        pos
# 24395       24395  ...        pos
# 24396       24396  ...        pos
# 24397       24397  ...        pos
#
# [24358 rows x 5 columns]

# %%
# df['scoring']=df['message_fr_en'][1000:1500].apply(lambda text:classifier([text]))

# %%
def classification(text):
  try:
    return classifier([text])
  except:
    return 'none'

# %%
text='hello word'
classification([text])
# Out:
# 'none'

# %%
df_fr['scoring']=df_fr['message_fr_en'].apply(classification)

# %%
df_fr['message_fr_en'][200:].head(50)
# Out:
# 200    stb is ✌ ✋ Suggests darlekbira Especially this...
# 201    it's true say direct credits it's been months ...
# 202    ana jebt devu car b milion mawefkouch wahabou ...
# 203                                 very good idea bravo
# 204                                            well done
# 205                                      congratulations
# 206                            congratulations good luck
# 207        mohamed taher lahmidi thank you bi how envenu
# 208    ￼ btc dogecoin bonus jackpot binance futures l...
# 209                                           thanks stb
# 210    card block tand double overdraft authorization...
# 211                    bravo good continuation good luck
# 212                                            good luck
# 213    bravo hoping well established stb direct corre...
# 214                                        good luck stb
# 215                                    bj problem please
# ...

# %%
df_fr['scoring'][2][0]['score']<0.98
# Out:
# False

# %%
df_fr['scoring'][18][0]['label']
# Out:
# 'POSITIVE'

# %%
# Out:
# 'NEGATIVE'

# %%
for i in range(0,len(df_fr)):
  try:
    if df_fr['scoring'][i][0]['score']<0.985:
      df_fr['score1'][i]='NEUTRAL'
    else:
      df_fr['score1'][i]=df_fr['scoring'][i][0]['label']
  except:
    print('none')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none

# %%
df_fr.to_csv('df_fr_score.csv')

# %%
df_fr['scoring'].head(50)
# Out:
# 0     [{'label': 'POSITIVE', 'score': 0.999061048030...
# 1     [{'label': 'POSITIVE', 'score': 0.999841809272...
# 2     [{'label': 'POSITIVE', 'score': 0.999078273773...
# 3     [{'label': 'POSITIVE', 'score': 0.999553620815...
# 4     [{'label': 'POSITIVE', 'score': 0.942747294902...
# 5     [{'label': 'POSITIVE', 'score': 0.942747294902...
# 6     [{'label': 'POSITIVE', 'score': 0.942747294902...
# 7     [{'label': 'POSITIVE', 'score': 0.942747294902...
# 8     [{'label': 'POSITIVE', 'score': 0.942747294902...
# 9     [{'label': 'POSITIVE', 'score': 0.942747294902...
# 10    [{'label': 'POSITIVE', 'score': 0.942747294902...
# 11    [{'label': 'POSITIVE', 'score': 0.942747294902...
# 12    [{'label': 'POSITIVE', 'score': 0.942747294902...
# 13    [{'label': 'POSITIVE', 'score': 0.942747294902...
# 14    [{'label': 'POSITIVE', 'score': 0.942747294902...
# 15    [{'label': 'POSITIVE', 'score': 0.942747294902...
# 16    [{'label': 'POSITIVE', 'score': 0.942747294902...
# ...

# %%
import pandas as pd
df_ar=pd.read_csv('/content/ar_to_en1.txt',names=['message_ar_en'])

# %%
import pandas as pd
df_ar1=pd.read_csv('/content/result_ar.csv')

# %%
df_ar
# Out:
#                                            message_ar_en
# 0      thank you very much head of agency ksibet medi...
# 1                                 thank you good service
# 2               yes superior supervision after stb bravo
# 3                               bravo stb always present
# 4                                                 sousse
# ...                                                  ...
# 24395             can change your account with bt credit
# 24396                              stb bank buys credits
# 24397  stb bank authorized page come lose bank card w...
# 24398  hellojai client stb i have direct credit remai...
# 24399  install best whatsapp cleaner save android pho...
#
# [24400 rows x 1 columns]

# %%
import pandas as pd
df_fr=pd.read_csv('/content/sample_data/fr999.csv')

# %%
import pandas as pd
df_ar=pd.read_csv('/content/sample_data/ar999.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd8 in position 117: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-b61ac9e6ca11> in <module>()
#       1 import pandas as pd
# ----> 2 df_ar=pd.read_csv('/content/sample_data/ar999.csv')
#
# ...

# %%
df_fr
# Out:
#        Unnamed: 0  ...                                         token_stem
# 0               0  ...  merci  beaucoup  chef  dagenc  ksibet  medioun...
# 1               1  ...  merci  beaucoup  chef  dagenc  ksibet  medioun...
# 2               2  ...                                merci  bon  servic
# 3               3  ...                                merci  bon  servic
# 4               4  ...             oui  supeur  encadr  aprè  stb  bravo
# ...           ...  ...                                                ...
# 23581       23581  ...                             crédit  islah  masken
# 23582       23582  ...  خدمات  🏇  نقل  🏇  وتوصيل  🚵  ‍  ♂  ️  🏇  🏇  😁 ...
# 23583       23583  ...  خدمات  🏇  نقل  🏇  وتوصيل  🚵  ‍  ♂  ️  🏇  🏇  😁 ...
# 23584       23584  ...  خدمات  🏇  نقل  🏇  وتوصيل  🚵  ‍  ♂  ️  🏇  🏇  😁 ...
# 23585       23585  ...  خدمات  🏇  نقل  🏇  وتوصيل  🚵  ‍  ♂  ️  🏇  🏇  😁 ...
#
# [23586 rows x 18 columns]

# %%
df_ar1['message_ar_en']
# Out:
# 0        thank you very much head of agency ksibet medi...
# 1                                   thank you good service
# 2                 yes superior supervision after stb bravo
# 3                                 bravo stb always present
# 4                                                   sousse
#                                ...
# 24395               can change your account with bt credit
# 24396                                stb bank buys credits
# 24397    stb bank authorized page come lose bank card w...
# 24398    hellojai client stb i have direct credit remai...
# 24399    install best whatsapp cleaner save android pho...
# Name: message_ar_en, Length: 24400, dtype: object

# %%
df_ar1[df_ar1['scoring']=='none']
# Out:
#        Unnamed: 0 message_ar_en scoring
# 1275         1275           NaN    none
# 1297         1297           NaN    none
# 1506         1506           NaN    none
# 1508         1508           NaN    none
# 3375         3375           NaN    none
# 4224         4224           NaN    none
# 5320         5320           NaN    none
# 5399         5399           NaN    none
# 5520         5520           NaN    none
# 6211         6211           NaN    none
# 6233         6233           NaN    none
# 6442         6442           NaN    none
# 6444         6444           NaN    none
# 8311         8311           NaN    none
# 9160         9160           NaN    none
# 10256       10256           NaN    none
# 10335       10335           NaN    none
# 10456       10456           NaN    none
# 11725       11725           NaN    none
# 11881       11881           NaN    none
# 13475       13475           NaN    none
# 13497       13497           NaN    none
# ...

# %%
df_fr['scoring1']=df_fr['message_fr_en1'].apply(classification)

# %%
df_fr['scoring1'][0][0]['score']
# Out:
# 0.9990610480308533

# %%
df_fr
# Out:
#        Unnamed: 0  ...                                           scoring1
# 0               0  ...  [{'label': 'POSITIVE', 'score': 0.999061048030...
# 1               1  ...  [{'label': 'POSITIVE', 'score': 0.999841809272...
# 2               2  ...  [{'label': 'POSITIVE', 'score': 0.999841809272...
# 3               3  ...  [{'label': 'POSITIVE', 'score': 0.999078273773...
# 4               4  ...  [{'label': 'POSITIVE', 'score': 0.999078273773...
# ...           ...  ...                                                ...
# 23581       23581  ...  [{'label': 'POSITIVE', 'score': 0.997966825962...
# 23582       23582  ...  [{'label': 'POSITIVE', 'score': 0.985265552997...
# 23583       23583  ...  [{'label': 'POSITIVE', 'score': 0.999838590621...
# 23584       23584  ...  [{'label': 'POSITIVE', 'score': 0.999865889549...
# 23585       23585  ...  [{'label': 'POSITIVE', 'score': 0.999819219112...
#
# [23586 rows x 19 columns]

# %%
for i in range(0,len(df_fr)):
  try:
    if df_fr['scoring1'][i][0]['score']<0.985:
      df_fr['score2'][i]='NEUTRAL'
    else:
      df_fr['score2'][i]=df_fr['scoring1'][i][0]['label']
  except:
    print('none')
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# ...

# %%
df_fr['score2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-56e8627d012e> in <module>()
# ----> 1 df_fr['score2']
#
# ...

# %%
df_ar1.to_csv('df_ar_score1.csv')

# %%
from tokenizers import Tokenizer

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

# %%
df1=df['message_fr_en']

# %%
message_encodings = tokenizer(text=text, truncation=True, padding=True, max_length=30)

# %%
message_encodings

# %%
text='good service in this resterant'
classifier(text)
# Out:
# [{'label': 'LABEL_0', 'score': 0.9974620342254639}]

# %%
df['message_fr_en']
# Out:
# 0        thank you very much head of agency ksibet medi...
# 1                                   thank you good service
# 2                    yes great supervision after stb bravo
# 3                                 bravo stb always present
# 4                                                   sousse
#                                ...
# 24393         can change an account with you jen credit bt
# 24394                                stb bank buys credits
# 24395    stb bank page authorized come and lose b card ...
# 24396    hello I have client stb I have direct credit r...
# 24397    install best whatsapp cleaner save android pho...
# Name: message_fr_en, Length: 24398, dtype: object

# %%
total_count = len(df)
max_batch = 1000
df['scoring']=df['message_fr_en'].apply(lambda text:classifier([text]))
 for i in range(0,total_count, max_batch):
    a=df['message_fr_en'][i:i+max_batch]
    for word in a:
        try:
            print(get_profile(word))
            time.sleep(rand)
        except:
            print('none')

# %%
df['scoring']
# Out:
# 0        [{'label': 'POSITIVE', 'score': 0.999061048030...
# 1        [{'label': 'POSITIVE', 'score': 0.999841809272...
# 2        [{'label': 'POSITIVE', 'score': 0.999078273773...
# 3        [{'label': 'POSITIVE', 'score': 0.999553620815...
# 4        [{'label': 'POSITIVE', 'score': 0.942747294902...
#                                ...
# 24393                                                  NaN
# 24394                                                  NaN
# 24395                                                  NaN
# 24396                                                  NaN
# 24397                                                  NaN
# Name: scoring, Length: 24398, dtype: object

# %%
# Out:
# 900                                                 mail
# 901                                                 mail
# 902    stb bank الشركة التونسية للبنك trace trace fab...
# 903                                                reply
# 904                                                reply
# 905                                           reply mail
# 906                                                reply
# 907                                             RepON is
# 908                                               doctor
# 909    i hope Participates win ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ...
# 910                                                reply
# 911    i hope Participates win ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ...
# 912    i hope Participates win ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ...
# 913    i hope Participates win ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ...
# 914    partic ipe i hope win ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ...
# 915    i hope Participates win ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ️ ❤ ...
# ...
